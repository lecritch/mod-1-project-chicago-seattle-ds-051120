# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns

module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.data_cleaning import data_cleaning as dc

# %% [markdown]
# # Part 2 Analysis:

# %% [markdown]
# In Part 2 of this analysis, we find an updated estimate on the number of Opportunity Youth in South King County.
#
# We will then dive deeper into this population by breaking down the number of Opportunity Youth by puma code and by age groups.

# %% [markdown]
# ### 1. Updated Count:
#
# From our analysis, we found that there are 6723 Opportunity Youth in South King County.

# %%
# create skc df and then subset the OY population:
skc_df = dc.final_skc_df()
oy_df = skc_df[skc_df['is_oy']]
oy_df['person_weight'].sum()
# Out:
# 6723.0

# %% [markdown]
# ### 2. Count by PUMA:
#
# We defined South King County by the following 4 puma codes:

# %%
puma_names = dc.create_skc_puma_df()
puma_names
# Out:
#    state_fips                                         state_name cpuma0010  \
# 42         53  Washington                                    ...      1044
# 43         53  Washington                                    ...      1044
# 44         53  Washington                                    ...      1044
# 47         53  Washington                                    ...      1046
#
#      puma    geoid    gisjoin  \
# 42  11613  5311613  G53011613
# 43  11614  5311614  G53011614
# 44  11615  5311615  G53011615
# 47  11612  5311612  G53011612
#
#                                             puma_name
# 42  King County (Southwest Central)--Kent City    ...
# 43  King County (Southwest)--Auburn City & Lakelan...
# 44  King County (Southeast)--Maple Valley, Covingt...
# 47  King County (Far Southwest)--Federal Way, Des ...

# %% [markdown]
# We can see the break down of the Opportunity Youth population by PUMA code as follows:

# %%
dc.puma_breakdown(oy_df)
# Out:
# PUMA 11612: 1977.0
# PUMA 11613: 2006.0
# PUMA 11614: 1530.0
# PUMA 11615: 1210.0

# %% [markdown]
# ![pop_ages.png](/reports/figures/pop_ages.png)

# %% [markdown]
# ### 3. Count by Age Group:
#
# When categorising the OY population into three age groups: 16-18, 19-21, 22-24, we can see a trend in how this population is dispersed:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Comparing Education Attainment Amongst Opportunity Youth:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# State the combined numbers / %ages for OY.
#
# Compared to non-oy ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. Opportunity Youth Employment Information:
#
# We get some interesting insights when looking into whether Opportunity Youth are available for work and looking for work.  This calls for further investigation.

# %% [markdown]
# #### OY Available for Work:
# List the data - total numbers without the age group breakdown

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### OY Looking for Work:
#
# More interestingly, was the information reported for the number of OY looking for work.  While 12% did not report, 57% reported they were not looking for work.  This leads to questioning why this unemployed population is not seeking employment.

# %% [markdown]
# ![image.png](attachment:image.png)
