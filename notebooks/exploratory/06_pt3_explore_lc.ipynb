# %%
def imports():
    import psycopg2
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt

    # Establish DB:
    DBNAME = "opportunity_youth"

    # Create a connection to db
    conn = psycopg2.connect(dbname=DBNAME)

# %%
# Run the above created function to get imports and database:
imports()

# %%
def skc_df():
    import psycopg2
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt

    # Establish DB:
    DBNAME = "opportunity_youth"

    # Create a connection to db
    conn = psycopg2.connect(dbname=DBNAME)
    
    skc_puma_codes = ['11613', '11614', '11615', '11612']
    
    QUERY = """
    SELECT rt AS record_type, serialno AS id, agep AS age, sex, st, pwgtp AS person_weight, puma, sch AS school_enrollment, schl AS education_attained, 
            esr AS employment_status, nwab AS absent_from_work, nwav AS avail_for_work, nwla AS layoff, nwlk AS look_for_work
    FROM pums_2017
    WHERE agep BETWEEN 16 AND 24"""

    relevant_ages_pums = pd.read_sql(QUERY, conn)
    skc_df = relevant_ages_pums[relevant_ages_pums['puma'].isin(skc_puma_codes)]    
    
    return skc_df

# %%
skc_df = skc_df()

# %%
# All of SKC data for persons aged 16-24
skc_df
# Out:
#       record_type             id   age sex  st  person_weight   puma  \
# 32              P  2013000007063  19.0   1  53           30.0  11612
# 36              P  2013000008046  17.0   2  53           36.0  11613
# 48              P  2013000011255  17.0   2  53           13.0  11614
# 54              P  2013000012970  21.0   2  53           29.0  11612
# 57              P  2013000013525  18.0   2  53           24.0  11613
# ...           ...            ...   ...  ..  ..            ...    ...
# 37134           P  2017001386502  18.0   1  53           17.0  11613
# 37684           P  2017001464049  21.0   2  53           18.0  11613
# 37718           P  2017001470135  23.0   1  53           17.0  11613
# 38050           P  2017001518359  18.0   1  53           20.0  11613
# 38130           P  2017001530818  23.0   1  53           26.0  11613
#
#       school_enrollment education_attained employment_status absent_from_work  \
# 32                    2                 18                 6                2
# 36                    2                 13                 6                2
# 48                    2                 12                 6                2
# 54                    3                 18                 6                2
# 57                    2                 15                 6                2
# ...                 ...                ...               ...              ...
# 37134                 1                 11                 6                3
# 37684                 1                 16                 6                3
# 37718                 1                 14                 6                3
# 38050                 1                 11                 6                3
# 38130                 1                 21                 1                2
#
#       avail_for_work layoff look_for_work
# 32                 5      2             2
# 36                 5      2             2
# 48                 5      2             2
# 54                 5      2             2
# 57                 5      2             2
# ...              ...    ...           ...
# 37134              5      3             3
# 37684              5      3             3
# 37718              5      3             3
# 38050              5      3             3
# 38130              3      2             2
#
# [2359 rows x 14 columns]

# %%
# Add 2 new columns:  
skc_df['age_group'] = 'assign vals'
skc_df['is_oy'] = 'assign bool'

# %%
# Preview:
skc_df
# Out:
#       record_type             id   age sex  st  person_weight   puma  \
# 32              P  2013000007063  19.0   1  53           30.0  11612
# 36              P  2013000008046  17.0   2  53           36.0  11613
# 48              P  2013000011255  17.0   2  53           13.0  11614
# 54              P  2013000012970  21.0   2  53           29.0  11612
# 57              P  2013000013525  18.0   2  53           24.0  11613
# ...           ...            ...   ...  ..  ..            ...    ...
# 37134           P  2017001386502  18.0   1  53           17.0  11613
# 37684           P  2017001464049  21.0   2  53           18.0  11613
# 37718           P  2017001470135  23.0   1  53           17.0  11613
# 38050           P  2017001518359  18.0   1  53           20.0  11613
# 38130           P  2017001530818  23.0   1  53           26.0  11613
#
#       school_enrollment education_attained employment_status absent_from_work  \
# 32                    2                 18                 6                2
# 36                    2                 13                 6                2
# 48                    2                 12                 6                2
# 54                    3                 18                 6                2
# 57                    2                 15                 6                2
# ...                 ...                ...               ...              ...
# 37134                 1                 11                 6                3
# 37684                 1                 16                 6                3
# 37718                 1                 14                 6                3
# 38050                 1                 11                 6                3
# 38130                 1                 21                 1                2
#
#       avail_for_work layoff look_for_work    age_group        is_oy
# 32                 5      2             2  assign vals  assign bool
# 36                 5      2             2  assign vals  assign bool
# 48                 5      2             2  assign vals  assign bool
# 54                 5      2             2  assign vals  assign bool
# 57                 5      2             2  assign vals  assign bool
# ...              ...    ...           ...          ...          ...
# 37134              5      3             3  assign vals  assign bool
# 37684              5      3             3  assign vals  assign bool
# 37718              5      3             3  assign vals  assign bool
# 38050              5      3             3  assign vals  assign bool
# 38130              3      2             2  assign vals  assign bool
#
# [2359 rows x 16 columns]

# %%
# Create oy employment/school variables:
oy_employment_status = ['3', '6']
oy_school_enrollment = ['1']

# %%
# Assign values to 'is_oy'
skc_df['is_oy'] = (skc_df['employment_status'].isin(oy_employment_status)) & (skc_df['school_enrollment'].isin(oy_school_enrollment))

# %%
# Create age_group variables:
ages_1 = [16, 17, 18]
g1 = 'Ages 16-18'
ages_2 = [19, 20, 21]
g2 = 'Ages 19-21'
ages_3 = [22, 23, 24]
g3 = 'Ages 22-24'

ages_dict = {g1: ages_1, g2: ages_2, g3: ages_3}

# %%
# Assign values to 'age_group'
# skc_df['age_group'] = [lambda key, val: if x['age'].isin(ages_dict[x])]

# skc_df['age_group'] = [key for key, val in ages_dict if skc_df['age'] in val]

# [x for x in range(len(skc_df))]

# [x * x for x in range(10) if x % 2 == 0]

[key for key, val in ages_dict if skc_df['age'] in val]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a39fc1fa9c1c> in <module>
#       8 # [x * x for x in range(10) if x % 2 == 0]
#       9
# ---> 10 [key for key, val in ages_dict if skc_df['age'] in val]
#
# <ipython-input-30-a39fc1fa9c1c> in <listcomp>(.0)
#       8 # [x * x for x in range(10) if x % 2 == 0]
#       9
# ---> 10 [key for key, val in ages_dict if skc_df['age'] in val]
#
# ValueError: too many values to unpack (expected 2)

# %%
# lambda x: if x.isin(ages_dict[x])

skc_df
# Out:
#       record_type             id   age sex  st  person_weight   puma  \
# 32              P  2013000007063  19.0   1  53           30.0  11612
# 36              P  2013000008046  17.0   2  53           36.0  11613
# 48              P  2013000011255  17.0   2  53           13.0  11614
# 54              P  2013000012970  21.0   2  53           29.0  11612
# 57              P  2013000013525  18.0   2  53           24.0  11613
# ...           ...            ...   ...  ..  ..            ...    ...
# 37134           P  2017001386502  18.0   1  53           17.0  11613
# 37684           P  2017001464049  21.0   2  53           18.0  11613
# 37718           P  2017001470135  23.0   1  53           17.0  11613
# 38050           P  2017001518359  18.0   1  53           20.0  11613
# 38130           P  2017001530818  23.0   1  53           26.0  11613
#
#       school_enrollment education_attained employment_status absent_from_work  \
# 32                    2                 18                 6                2
# 36                    2                 13                 6                2
# 48                    2                 12                 6                2
# 54                    3                 18                 6                2
# 57                    2                 15                 6                2
# ...                 ...                ...               ...              ...
# 37134                 1                 11                 6                3
# 37684                 1                 16                 6                3
# 37718                 1                 14                 6                3
# 38050                 1                 11                 6                3
# 38130                 1                 21                 1                2
#
#       avail_for_work layoff look_for_work  age_group  is_oy
# 32                 5      2             2          0  False
# 36                 5      2             2          1  False
# 48                 5      2             2          2  False
# 54                 5      2             2          3  False
# 57                 5      2             2          4  False
# ...              ...    ...           ...        ...    ...
# 37134              5      3             3       2354   True
# 37684              5      3             3       2355   True
# 37718              5      3             3       2356   True
# 38050              5      3             3       2357   True
# 38130              3      2             2       2358  False
#
# [2359 rows x 16 columns]
