# %% [markdown]
# ## Questions Sparked by Plots:

# %% [markdown]
# ### Population Comparison 2016 vs. 2017:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Can see there's a large discrepancy between the OY populations of 2016 and 2017
# - This sparks further questioning:
#     - Did the 2016 use a larger area than just South King County - our data was just generated using the puma codes of the south districts of King County
#         - Is our data too refined?
#         - If we looked at the oy population of all of King County, would we get similar numbers to 2016?
#         - Have we defined South King County correctly?
#      - 2016 seems to be proportionately large with each age group, so perhaps if we look into the percentages of the oy population to the overall population of 16-24 year olds, we'll be able to see if there's been any change in the proportion of oy per age group... we actually did look into this...

# %% [markdown]
# ### OY Percentages of Age Groups 2016 vs. 2017:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - From here we can see that the proportions of each age group of OY is actually very similar.
# - Further questioning:
#     - Why are 19-24yos holding the higher population amongst oy?  This could be sugested that maybe 16-18 have more support to stay in school where as 19-24yos have less accountability
#         - Thus, what accounability systems are in place to help these age group re-engage with education and/or work?

# %% [markdown]
# ### 2017 OY Population:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - We can see this upward trend again between the groups.
# - Further questioning:
#     - Why is the OY population highest for the 22-24 age group?
#     - How are these groups split between gender, race, income even?
#     - Is there anything specific about SKC that influences this trend?  If we compared to the wider King County population would we see the same trend?

# %% [markdown]
# ### Gender OY population by age group:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Not a huge discrepancy between gender

# %% [markdown]
# ### Percentage of education level:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Further questions:
#     - 22-24yos seem to have attained some level of education so why aren't they working?
#     - Makes sense that the 16-18 don't hold qualifications given that they are most likely drop outs - should have degree either
#     - Is the blue slither in 16-18 an outlier since it's so small and it's unlikely for that age group to do college credits?
#     - Do these age groups still live at home?  How much does their living situation determine whether they are educated/working?
