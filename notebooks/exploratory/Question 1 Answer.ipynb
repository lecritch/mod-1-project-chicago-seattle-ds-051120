# %%
# Imports:
import psycopg2
import pandas as pd

# Establish DB:
DBNAME = "opportunity_youth"

# Create a connection to db
#conn = psycopg2.connect(dbname=DBNAME)
conn = psycopg2.connect(dbname='postgres',user='postgres',password='admin')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#kc.display.max_colwidth

# Example query format:
# pd.read_sql("SELECT * FROM pums_2017 LIMIT 10;", conn)

# %%
wa_geo_xwalk = pd.read_sql("SELECT * FROM wa_geo_xwalk Join ct_puma_xwalk ON", conn)
wa_geo_xwalk
# Out:
#              tabblk2010  st stusps  \
# 0       530630112024017  53     WA
# 1       530630105031024  53     WA
# 2       530630101001010  53     WA
# 3       530630101001014  53     WA
# 4       530630101001020  53     WA
# ...                 ...  ..    ...
# 195569  530139602005011  53     WA
# 195570  530139602005004  53     WA
# 195571  530239703002115  53     WA
# 195572  530239703002336  53     WA
# 195573  530239703002386  53     WA
#
#                                                    stname    cty  \
# 0       Washington                                    ...  53063
# 1       Washington                                    ...  53063
# 2       Washington                                    ...  53063
# 3       Washington                                    ...  53063
# 4       Washington                                    ...  53063
# ...                                                   ...    ...
# 195569  Washington                                    ...  53013
# ...

# %%
kc=pd.DataFrame(wa_geo_xwalk)
kc=kc[kc['ctyname'].str.match("^King County*")== True]
kc
# Out:
#              tabblk2010  st stusps  \
# 114     530330325001075  53     WA
# 115     530330328003235  53     WA
# 116     530330297003059  53     WA
# 117     530330270002001  53     WA
# 118     530339901000053  53     WA
# ...                 ...  ..    ...
# 194245  530339901000079  53     WA
# 194246  530339901000019  53     WA
# 194247  530339901000062  53     WA
# 194248  530339901000034  53     WA
# 195158  530330093001049  53     WA
#
#                                                    stname    cty  \
# 114     Washington                                    ...  53033
# 115     Washington                                    ...  53033
# 116     Washington                                    ...  53033
# 117     Washington                                    ...  53033
# 118     Washington                                    ...  53033
# ...                                                   ...    ...
# 194245  Washington                                    ...  53033
# ...

# %%
kc[kc['tabblk2010','trctname','bgrpname','zcta']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('tabblk2010', 'trctname', 'bgrpname', 'zcta')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-cf3a99d9bc79> in <module>
# ...

# %% [markdown]
# #Forming the South King County Data

# %%
skc=kc[kc['bgrpname'].str.startswith("3")== True]
#skc=kc[kc["bgrpname"].endswith("")== True]
skc
# Out:
#              tabblk2010  st stusps  \
# 115     530330328003235  53     WA
# 116     530330297003059  53     WA
# 121     530330276003004  53     WA
# 122     530330283003052  53     WA
# 123     530330283003079  53     WA
# ...                 ...  ..    ...
# 193408  530330311003018  53     WA
# 193409  530330311003021  53     WA
# 193421  530330312023007  53     WA
# 193432  530330317033012  53     WA
# 193433  530330317033005  53     WA
#
#                                                    stname    cty  \
# 115     Washington                                    ...  53033
# 116     Washington                                    ...  53033
# 121     Washington                                    ...  53033
# 122     Washington                                    ...  53033
# 123     Washington                                    ...  53033
# ...                                                   ...    ...
# 193408  Washington                                    ...  53033
# ...

# %%
import folium
#king_county= 

us = folium.Map([47.707243, 47.707243], zoom_start=10)
us
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
kc_cords=kc[['blklatdd','blklondd']]
kc_cords["blklatdd"][114]

# %%
skc_cords=skc[['blklatdd','blklondd']]
skc_cords

# %% [markdown]
# 1.A map that visualizes which parts of King County
# are a part of South King County:
